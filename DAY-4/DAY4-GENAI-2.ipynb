# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
gK = os.getenv('GROQ_API_KEY')
llm = ChatGroq(model='Llama3-8b-8192',groq_api_key=gK)

os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN')

from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("LVMActivity.pdf")
docs = loader.load()
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
splits = text_splitter.split_documents(docs)
vectorstore = Chroma.from_documents(documents=splits,embedding=embeddings)
retriver = vectorstore.as_retriever()

# %%
system_prompt - Controls the overall AI response

# %%
system_prompt = ("You are AI assistant from QA tasks"
                 "say don't answer"
                 "\n\n"
                 "{context}")
prompt = ChatPromptTemplate.from_messages([("system",system_prompt),("human","{input}"),])

qa_chain  = create_stuff_documents_chain(llm,prompt)
rag_chain = create_retrieval_chain(retriver,qa_chain)
response = rag_chain.invoke({'input':'what is LVM'})
#print(response)
print(response['answer'])
#summary_chain.run(response['answer'])
# Out:
# I'm not supposed to answer, so I won't.

# %%
system_prompt = ("You are AI assistant from QA tasks"
                 "If you don't know the answer,say don't know"
                 "\n\n"
                 "{context}")
prompt = ChatPromptTemplate.from_messages([("system",system_prompt),("human","{input}"),])

qa_chain  = create_stuff_documents_chain(llm,prompt)
rag_chain = create_retrieval_chain(retriver,qa_chain)
response = rag_chain.invoke({'input':'How to create '})
#print(response)
print(response['answer'])
#summary_chain.run(response['answer'])
# Out:
# Based on the provided information, here is the step-by-step guide to create a logical volume, thin pool, and thinly provisioned volumes:
#
# **Step 5: Create a logical volume**
#
# 1. Use the `lvcreate` command to create a 500 MB logical volume named `myvol` from the `myvolg` volume group:
# ```
# # lvcreate -v --L 500m --n myvol myvolg
# ```
# **Step 6: Display information about the logical volume**
#
# a. Use the `lvdisplay` command to display attributes of the logical volume:
# ```
# # lvdisplay
# ```
# b. Use the `lvs` command to report information in a more condensed form:
# ```
# # lvs
# ```
# c. Use the `lvscan` command to scan all disks for logical volumes:
# ```
# # lvscan
# ```
# d. Use the `pvs` command to display information about the physical volumes:
# ```
# # pvs
# ```
#
# **Step 3: Create a thin pool**
#
# a. Use the `lvcreate` command to create a 100 MB thin pool named `mythinpool` in the `myvolg` volume group:
# ```
# # lvcreate -v --L 100m --T myvolg/mythinpool
# ...

# %%
print(response)
# Out:
# {'input': 'How to create ', 'context': [Document(metadata={'page': 5, 'source': 'LVMActivity.pdf'}, page_content='5. Create a logical volume. \nUse the lvcreate command to create a 500 MB logical volume named myvol from the \nmyvolg volume group. \n# lvcreate -v –L 500m –n myvol myvolg \nSetting logging type to disk \nFinding volume group “myvolg” \nArchiving volume group “myvolg” metadata (seqno 1). \nCreating logical volume myvol \n... \nLogical volume “myvol” created \n6. Display information about the logical volume. \na. Use the lvdisplay command to display attributes of the logical volume. \n# lvdisplay \n--- Logical volume --- \nLV Path /dev/myvolg/myvol \nLV Name myvol \nVG Name myvolg \n... \nLV Size 500.00 MiB \n... \nb. Use the lvs command to report information in a more condensed form. \n# lvs \nLV VG Attr LSize Pool Origin Data% Move Log... \nmyvol myvolg -wi-a----- 500.00m \n \nc. Use the lvscan command to scan all disks for logical volumes. \n# lvscan \nACTIVE ‘/dev/myv
# ...

# %% [raw]
# C:\Users\theeba>python
# Python 3.13.0 (tags/v3.13.0:60403a5, Oct  7 2024, 09:38:07) [MSC v.1941 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# >>> import sqlite3
# >>> sqlite3.connect
# <built-in function connect>
# >>>
# >>> sqlite3.connect("Test1.db")
# <sqlite3.Connection object at 0x0000022404B9EF20>
# >>>
# >>> con = sqlite3.connect("Test1.db")
# >>> con.cursor()
# <sqlite3.Cursor object at 0x0000022404C5F1C0>
# >>> sth = con.cursor()
# >>> sth.execute('create table T1(id INT,name Text)")
#   File "<python-input-9>", line 1
#     sth.execute('create table T1(id INT,name Text)")
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)
# >>>
# >>> sth.execute('create table T1(id INT,name Text)')
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>> sth.execute("insert into T1 values(101,'prodA')")
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>>
# >>> Va=102
# >>> Vb='prodB'
# >>>
# >>> sth.execute("insert into T1 values(?,?)",(Va,Vb))
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>>
# >>> sth.execute("select *from T1")
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>>
# >>> sth.fetchall()
# [(101, 'prodA'), (102, 'prodB')]
# >>>
# >>> sth.execute("select *from T1")
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>> sth.fetchone()
# (101, 'prodA')
# >>> sth.fetchone()
# (102, 'prodB')
# >>>
# >>> sth.execute("select *from T1")
# <sqlite3.Cursor object at 0x0000022404C5EFC0>
# >>>
# >>> for var in sth:
# ...     print(var)
# ...
# (101, 'prodA')
# (102, 'prodB')
# >>>
# >>> conn.commit()
# Traceback (most recent call last):
#   File "<python-input-31>", line 1, in <module>
#     conn.commit()
#     ^^^^
# NameError: name 'conn' is not defined. Did you mean: 'con'?
# >>> con.commit()
# >>>
# >>> exit()
#
# C:\Users\theeba>python
# Python 3.13.0 (tags/v3.13.0:60403a5, Oct  7 2024, 09:38:07) [MSC v.1941 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# >>> import sqlite3
# >>>
# >>> con = sqlite3.connect("Test1.db")
# >>> sth = con.cursor()
# >>> sth.execute("select *from T1")
# <sqlite3.Cursor object at 0x000002835BC4F1C0>
# >>> sth.fetchall()
# [(101, 'prodA'), (102, 'prodB')]
# >>>
# >>> sth.execute("select *from T1")
# <sqlite3.Cursor object at 0x000002835BC4F1C0>
# >>>
# >>> r = sth.fetchone()
# >>>
# >>> 'prodA' in r
# True
# >>> 'prodC' in r
# False
# >>>
# >>> r
# (101, 'prodA')
# >>>
# >>> if(sth.fetchone()):
# ...     print('prodA is exists')
# ... else:
# ...     print('prodA is not exists')
# ...
# prodA is exists
# >>>
# >>> bool(None)
# False
# >>> bool('')
# False
# >>> bool(0)
# False
# >>> bool([]),bool(()),bool({}),bool(0.0)
# (False, False, False, False)
# >>>

# %%
Fine-Tuning
--------------
eye       -> French
(english)    

Get dataset - domain-specific
-----------
Fine-Tuning a GPT/GPT-3/..
     |-> load your data # API -> jsonFormat 
     |->   jsonrecursivel split

openai.FineTune.create(training_file="<uploadedJson/excel/csv/DB/urlID>",
                       model="fine-tuneModel")
|
openai.Completion.create(model=<fine-tuneModel>,prompt="eye to french",max_token=Count)
|
response
|
evaluation
